# %%
import pandas as pd
import numpy as np

# %%
# import the datasets from web scraper
df1 = pd.read_csv('IndeedDataAnalyst_2023.csv')
df2 = pd.read_csv('IndeedDataEngineer_2023.csv')
df3 = pd.read_csv('IndeedDataScientist_2023.csv')
df4 = pd.read_csv('simplyhiredjobs.csv')
df5 = pd.read_csv('dice_data_with_skills.csv')
df_new = pd.read_csv('FinalJobDataUpdated.csv')

# %%
# Indeed datasets
df1.insert(0, 'job_query', 'Data Analyst')
df2.insert(0, 'job_query', 'Data Engineer')
df3.insert(0, 'job_query', 'Data Scientist')

# %%
# combine datasets together
df = pd.concat([df1, df2, df3])

# %%
# format column headers
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.lower()
df = df.drop(columns='unnamed:_0')

# %%
# insert new column
df.insert(0, 'job_website_source', 'Indeed')

# %%
df.head()
# Out:
#   job_website_source     job_query  \
# 0             Indeed  Data Analyst
# 1             Indeed  Data Analyst
# 2             Indeed  Data Analyst
# 3             Indeed  Data Analyst
# 4             Indeed  Data Analyst
#
#                                            job_title  \
# 0            Board Certified Behavior Analyst (BCBA)
# 1                      Business Analyst II, Research
# 2  Business Analyst (New Holland, PA or Napoleon,...
# 3                                     Data Analyst I
# 4         Data Standard Analyst - Biostatistics Team
#
#                              company  \
# 0             Aspire Learning Center
# 1                   KeyLogic Systems
# 2  Goodville Mutual Casualty Company
# 3                        Salus Group
# 4                      Medpace, Inc.
#
#                                    location                    salary  \
# 0    100 Cummings Center, Beverly, MA 01915         $40 - $70 an hour
# 1                            Morgantown, WV                         N
# 2      625 W Main St, New Holland, PA 17557                         N
# 3  Sterling Heights, MI 48310•Hybrid remote  $60,829 - $67,720 a year
# 4        Cincinnati, OH 45227•Hybrid remote                         N
#
#                                      job_description
# 0  ASPIRE LEARNING CENTER, LLC\nJob Title: Board ...
# 1  KeyLogic Systems has an immediate need for a B...
# 2  Nature of Job\nServe as subject matter expert ...
# 3  Salus Group has been around conducting busines...
# 4  Job Summary:\nOur corporate activities are gro...

# %%
# drop records where salary is less than 40,000
df = df[df['salary'].str.replace(',', '').str.extract(r'(\d+)', expand=False).fillna('0').astype(int) >= 40000]

# split salary column into separate yearly min and max columns
df[['Yearly Min', 'Yearly Max']] = df['salary'].str.replace(',', '').str.extract(r'(\d+)\D*(\d+)?', expand=True).astype(float).fillna(0)

# set yearly max to yearly min if value is 0
df['Yearly Max'] = df.apply(lambda row: row['Yearly Min'] if row['Yearly Max'] == 0 else row['Yearly Max'], axis=1)

# remove the salary column
df = df.drop('salary', axis=1)

# format yearly min and yearly max columns as strings with two decimal places
df[['Yearly Min', 'Yearly Max']] = df[['Yearly Min', 'Yearly Max']].applymap('{:.2f}'.format)

# %%
df.dtypes
# Out:
# job_website_source    object
# job_query             object
# job_title             object
# company               object
# location              object
# job_description       object
# Yearly Min            object
# Yearly Max            object
# dtype: object

# %%
# add skills column by searching matching list of keywords for each record
if 'Skills' not in df.columns:
    df['Skills'] = ''

# define the list of keywords
keywords = ['SQL', 'Python', 'Big Data', 'AWS', 'ETL', 'Hadoop', 'Spark', 'Kafka', 'Data Warehousing', 'Data Pipelines', 
            'Data Modeling', 'Java', 'Database Management', 'NoSQL', 'Airflow', 'Docker', 'Kubernetes', 'Redshift', 
            'Snowflake', 'Data Integration', 'Excel', 'Tableau', 'Data Visualization', 'Data Analysis', 'Dashboards', 
            'Reporting', 'Business Intelligence', 'Data Mining', 'Statistics', 'Power BI', 'Data Cleansing', 
            'Data Interpretation', 'Google Analytics', 'Data Modelling', 'Predictive Analytics', 'R$', 'Data Mapping', 
            'Machine Learning', 'Deep Learning', 'Natural Language Processing', 'Predictive Modeling', 
            'Mathematical Modeling', 'TensorFlow', 'Keras', 'Computer Vision', 'Artificial Intelligence']

# loop over the records in the dataframe and update the skills column
for index, row in df.iterrows():
    job_description = row['job_description']
    skills = []
    for keyword in keywords:
        if keyword.lower() in job_description.lower():
            if keyword.lower() == 'r$':
                if 'ruby' in job_description.lower():
                    continue
            skills.append(keyword)
    row['Skills'] = ', '.join(skills)

# %%
df.head()
# Out:
#    job_website_source     job_query                     job_title  \
# 3              Indeed  Data Analyst                Data Analyst I
# 5              Indeed  Data Analyst        Technical Data Analyst
# 7              Indeed  Data Analyst                  Data Analyst
# 9              Indeed  Data Analyst         Data Analyst - Remote
# 12             Indeed  Data Analyst  Entry Level Business Analyst
#
#             company                                  location  \
# 3       Salus Group  Sterling Heights, MI 48310•Hybrid remote
# 5   Althea US, Inc.    Goodlettsville, TN 37072•Hybrid remote
# 7      Atmosfy, Inc                                    Remote
# 9          HSS Inc.                             United States
# 12   Microflexinfra                                    Remote
#
#                                       job_description Yearly Min Yearly Max  \
# 3   Salus Group has been around conducting busines...   60829.00   67720.00
# 5   As technical data analyst, you will be respons...   65000.00   75000.00
# 7   A BIT ABOUT YOU:\nYou're passionate and extrem...   60000.00   90000.00
# 9   Overview:\nThis position performs data analysi...   70000.00   80000.00
# 12  Microflexinfra focuses on providing business p...   65000.00   85000.00
#
#                                                Skills
# 3                                    Excel, Reporting
# 5                        Excel, Dashboards, Reporting
# 7                         SQL, AWS, Excel, Dashboards
# 9   SQL, Excel, Tableau, Data Analysis, Dashboards...
# 12

# %%
# regex pattern to parse city and state from location column
city_pattern = r'([A-Za-z]+(?: [A-Za-z]+)*)'
state_pattern = r'([A-Z]{2})'

# %%
# create new columns for city and state
df['city'] = df['location'].str.extract(city_pattern, expand=False)
df['state'] = df['location'].str.extract(state_pattern, expand=False)

# %%
df.head(10)
# Out:
#    job_website_source     job_query                     job_title  \
# 3              Indeed  Data Analyst                Data Analyst I
# 5              Indeed  Data Analyst        Technical Data Analyst
# 7              Indeed  Data Analyst                  Data Analyst
# 9              Indeed  Data Analyst         Data Analyst - Remote
# 12             Indeed  Data Analyst  Entry Level Business Analyst
# 15             Indeed  Data Analyst           HR Business Analyst
# 16             Indeed  Data Analyst                  Data Analyst
# 18             Indeed  Data Analyst              Business Analyst
# 21             Indeed  Data Analyst                  Data Analyst
# 22             Indeed  Data Analyst                  Data Analyst
#
#                       company                                  location  \
# 3                 Salus Group  Sterling Heights, MI 48310•Hybrid remote
# 5             Althea US, Inc.    Goodlettsville, TN 37072•Hybrid remote
# 7                Atmosfy, Inc                                    Remote
# 9                    HSS Inc.                             United States
# 12             Microflexinfra                                    Remote
# 15  Premier Staffing Solution                            Washington, DC
# 16                      Honor                                    Remote
# 18                   KesarWeb                        Detroit, MI•Remote
# 21               Wilson Elser                          White Plains, NY
# 22                    FanDuel                New York, NY•Hybrid remote
#
#                                       job_description Yearly Min Yearly Max  \
# 3   Salus Group has been around conducting busines...   60829.00   67720.00
# 5   As technical data analyst, you will be respons...   65000.00   75000.00
# 7   A BIT ABOUT YOU:\nYou're passionate and extrem...   60000.00   90000.00
# 9   Overview:\nThis position performs data analysi...   70000.00   80000.00
# 12  Microflexinfra focuses on providing business p...   65000.00   85000.00
# 15  Position: HR Technology Business Analyst\nLoca...   80000.00  115000.00
# 16  Data Analyst\nWe’re looking for Data Analyst t...   92000.00  113000.00
# 18  KesarWeb is a custom software development comp...   84000.00   96000.00
# 21  4/3/23 | White Plains, NY\nWilson Elser’s Whit...   65000.00   85000.00
# 22  ABOUT FANDUEL GROUP\nFanDuel Group is a world-...   90000.00  115000.00
#
#                                                Skills              city state
# 3                                    Excel, Reporting  Sterling Heights    MI
# 5                        Excel, Dashboards, Reporting    Goodlettsville    TN
# 7                         SQL, AWS, Excel, Dashboards            Remote   NaN
# 9   SQL, Excel, Tableau, Data Analysis, Dashboards...     United States   NaN
# 12                                                               Remote   NaN
# 15                              AWS, Excel, Reporting        Washington    DC
# 16       SQL, Python, Excel, Data Analysis, Reporting            Remote   NaN
# 18                 SQL, Data Visualization, Reporting           Detroit    MI
# 21                              SQL, Excel, Reporting      White Plains    NY
# 22  SQL, Python, Excel, Data Visualization, Reporting          New York    NY

# %%
# regex pattern for searching hybrid and remote work in location column
hybrid_pattern = r'\bhybrid\b'  
remote_pattern = r'\bremote\b'

# %%
# create new hybrid/remote columns with Boolean values
df['hybrid'] = df['location'].str.contains(hybrid_pattern, case=False)
df['remote'] = df['location'].str.contains(remote_pattern, case=False)

# %%
df.head(10)
# Out:
#    job_website_source     job_query                     job_title  \
# 3              Indeed  Data Analyst                Data Analyst I
# 5              Indeed  Data Analyst        Technical Data Analyst
# 7              Indeed  Data Analyst                  Data Analyst
# 9              Indeed  Data Analyst         Data Analyst - Remote
# 12             Indeed  Data Analyst  Entry Level Business Analyst
# 15             Indeed  Data Analyst           HR Business Analyst
# 16             Indeed  Data Analyst                  Data Analyst
# 18             Indeed  Data Analyst              Business Analyst
# 21             Indeed  Data Analyst                  Data Analyst
# 22             Indeed  Data Analyst                  Data Analyst
#
#                       company                                  location  \
# 3                 Salus Group  Sterling Heights, MI 48310•Hybrid remote
# 5             Althea US, Inc.    Goodlettsville, TN 37072•Hybrid remote
# 7                Atmosfy, Inc                                    Remote
# 9                    HSS Inc.                             United States
# 12             Microflexinfra                                    Remote
# 15  Premier Staffing Solution                            Washington, DC
# 16                      Honor                                    Remote
# 18                   KesarWeb                        Detroit, MI•Remote
# 21               Wilson Elser                          White Plains, NY
# 22                    FanDuel                New York, NY•Hybrid remote
#
#                                       job_description Yearly Min Yearly Max  \
# 3   Salus Group has been around conducting busines...   60829.00   67720.00
# 5   As technical data analyst, you will be respons...   65000.00   75000.00
# 7   A BIT ABOUT YOU:\nYou're passionate and extrem...   60000.00   90000.00
# 9   Overview:\nThis position performs data analysi...   70000.00   80000.00
# 12  Microflexinfra focuses on providing business p...   65000.00   85000.00
# 15  Position: HR Technology Business Analyst\nLoca...   80000.00  115000.00
# 16  Data Analyst\nWe’re looking for Data Analyst t...   92000.00  113000.00
# 18  KesarWeb is a custom software development comp...   84000.00   96000.00
# 21  4/3/23 | White Plains, NY\nWilson Elser’s Whit...   65000.00   85000.00
# 22  ABOUT FANDUEL GROUP\nFanDuel Group is a world-...   90000.00  115000.00
#
#                                                Skills              city state  \
# 3                                    Excel, Reporting  Sterling Heights    MI
# 5                        Excel, Dashboards, Reporting    Goodlettsville    TN
# 7                         SQL, AWS, Excel, Dashboards            Remote   NaN
# 9   SQL, Excel, Tableau, Data Analysis, Dashboards...     United States   NaN
# 12                                                               Remote   NaN
# 15                              AWS, Excel, Reporting        Washington    DC
# 16       SQL, Python, Excel, Data Analysis, Reporting            Remote   NaN
# 18                 SQL, Data Visualization, Reporting           Detroit    MI
# 21                              SQL, Excel, Reporting      White Plains    NY
# 22  SQL, Python, Excel, Data Visualization, Reporting          New York    NY
#
#     hybrid  remote
# 3     True    True
# 5     True    True
# 7    False    True
# 9    False   False
# 12   False    True
# 15   False   False
# 16   False    True
# 18   False    True
# 21   False   False
# 22    True    True

# %%
# rename columns for final dataset
df = df.rename(columns={"job_website_source": "Job Website",
                   "job_query": "Search Parameter",
                   "job_title": "Job Title",
                   "company": "Company",
                  "location": "Location",
                  "job_description": "Job Description",
                  "city": "City",
                   "state": "State Code",
                   "hybrid": "Hybrid",
                   "remote": "Remote",
                  })

# %%
df.head()
# Out:
#    Job Website Search Parameter                     Job Title  \
# 3       Indeed     Data Analyst                Data Analyst I
# 5       Indeed     Data Analyst        Technical Data Analyst
# 7       Indeed     Data Analyst                  Data Analyst
# 9       Indeed     Data Analyst         Data Analyst - Remote
# 12      Indeed     Data Analyst  Entry Level Business Analyst
#
#             Company                                  Location  \
# 3       Salus Group  Sterling Heights, MI 48310•Hybrid remote
# 5   Althea US, Inc.    Goodlettsville, TN 37072•Hybrid remote
# 7      Atmosfy, Inc                                    Remote
# 9          HSS Inc.                             United States
# 12   Microflexinfra                                    Remote
#
#                                       Job Description Yearly Min Yearly Max  \
# 3   Salus Group has been around conducting busines...   60829.00   67720.00
# 5   As technical data analyst, you will be respons...   65000.00   75000.00
# 7   A BIT ABOUT YOU:\nYou're passionate and extrem...   60000.00   90000.00
# 9   Overview:\nThis position performs data analysi...   70000.00   80000.00
# 12  Microflexinfra focuses on providing business p...   65000.00   85000.00
#
#                                                Skills              City  \
# 3                                    Excel, Reporting  Sterling Heights
# 5                        Excel, Dashboards, Reporting    Goodlettsville
# 7                         SQL, AWS, Excel, Dashboards            Remote
# 9   SQL, Excel, Tableau, Data Analysis, Dashboards...     United States
# 12                                                               Remote
#
#    State Code  Hybrid  Remote
# 3          MI    True    True
# 5          TN    True    True
# 7         NaN   False    True
# 9         NaN   False   False
# 12        NaN   False    True

# %%
# convert salary columns from string to float
df['Yearly Min'] = df['Yearly Min'].astype(float)
df['Yearly Max'] = df['Yearly Max'].astype(float)

# %%
# check datatypes particulary for salary to be numeric for calculations
df.dtypes
# Out:
# Job Website          object
# Search Parameter     object
# Job Title            object
# Company              object
# Location             object
# Job Description      object
# Yearly Min          float64
# Yearly Max          float64
# Skills               object
# City                 object
# State Code           object
# Hybrid                 bool
# Remote                 bool
# dtype: object

# %%
# start of SimplyHired data cleaning

# %%
df4.insert(0, 'job_query', 'Data Engineer')
df4.insert(0, 'job_website_source', 'SimplyHired')

# %%
# convert the min salary column to numeric values, replace non-numeric values with NaN
df4['sal_min'] = pd.to_numeric(df4['sal_min'], errors='coerce')

# remove any records where salary is NaN
df4 = df4.dropna(subset=['sal_min'])

# %%
# convert the max salary column to numeric values, replace non-numeric values with NaN
df4['sal_max'] = pd.to_numeric(df4['sal_max'], errors='coerce')

# remove any records where salary is NaN
df4 = df4.dropna(subset=['sal_max'])

# %%
# convert hourly rates to yearly salary

def hourly_to_yearly(hourly_rate):
    return hourly_rate * 40 * 52  # 40 hours per week, 52 weeks per year

# create a new yearly min/max salary columns to standardize hourly and yearly pay rates
df4['Yearly Min'] = df4.apply(lambda x: x['sal_min'] if x['salary_type'] == 'yearly' else hourly_to_yearly(x['sal_min']), axis=1)
df4['Yearly Max'] = df4.apply(lambda x: x['sal_max'] if x['salary_type'] == 'yearly' else hourly_to_yearly(x['sal_max']), axis=1)

# %%
df4 = df4.drop('index', axis=1)

# %%
# regex pattern to search for hybrid and remote work
hybrid_pattern = r'\bhybrid\b'
remote_pattern = r'\bremote\b'

# %%
# create new hybrid/remote columns with Boolean values
df4['hybrid'] = df4['type'].str.contains(hybrid_pattern, case=False)
df4['remote'] = df4['type'].str.contains(remote_pattern, case=False)

# %%
df4 = df4.rename(columns={"job_website_source": "Job Website",
                   "job_query": "Search Parameter",
                   "title": "Job Title",
                   "company": "Company",
                  "location": "Location",
                    "skills": "Skills",
                  "job_description": "Job Description",
                  "city": "City",
                   "state": "State Code",
                   "hybrid": "Hybrid",
                   "remote": "Remote",
                  })

# %%
# drop columns not needed for final dataset
df4 = df4.drop(['type', 'salary', 'salary_type', 'sal_min', 'sal_max', 'sal_median', 'posted_date', 'origin'], axis=1)

# %%
# combine Indeed dataset with SimplyHired
df = pd.concat([df, df4])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1715 entries, 3 to 833
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job Website       1715 non-null   object
#  1   Search Parameter  1715 non-null   object
#  2   Job Title         1715 non-null   object
#  3   Company           1715 non-null   object
#  4   Location          1051 non-null   object
#  5   Job Description   1051 non-null   object
#  6   Yearly Min        1715 non-null   float64
#  7   Yearly Max        1715 non-null   float64
#  8   Skills            1149 non-null   object
#  9   City              1534 non-null   object
#  10  State Code        1256 non-null   object
#  11  Hybrid            1715 non-null   bool
#  12  Remote            1715 non-null   bool
# dtypes: bool(2), float64(2), object(9)
# memory usage: 164.1+ KB

# %%
df.tail()
# Out:
#      Job Website Search Parameter  \
# 826  SimplyHired    Data Engineer
# 827  SimplyHired    Data Engineer
# 828  SimplyHired    Data Engineer
# 830  SimplyHired    Data Engineer
# 833  SimplyHired    Data Engineer
#
#                                              Job Title            Company  \
# 826                                     Data Scientist         Blue Apron
# 827  Scientist I - Image Registration & Multimodal ...    Allen Institute
# 828                              Junior Data Scientist             Augray
# 830        Associate Director, Statistical Programming  SAGE Therapeutics
# 833  Director, Commercial Data Science and Decision...  SAGE Therapeutics
#
#     Location Job Description  Yearly Min  Yearly Max     Skills        City  \
# 826      NaN             NaN     99400.0     12600.0        NaN    New York
# 827      NaN             NaN     80253.0    112355.0        NaN     Seattle
# 828      NaN             NaN     55000.0     60000.0        NaN  Brookfield
# 830      NaN             NaN    150923.0    207519.0        NaN         NaN
# 833      NaN             NaN    175642.0    241508.0  Analytics         NaN
#
#     State Code  Hybrid  Remote
# 826         NY   False   False
# 827         WA   False   False
# 828         WI   False   False
# 830        NaN   False    True
# 833         MA   False   False

# %%
# start of Dice data cleaning

# %%
# insert new columns to categorize job website and job title searched
df5.insert(0, 'job_query', 'Data Scientist')
df5.insert(0, 'job_website_source', 'dice.com')

# %%
# convert hourly rates to yearly salary

def hourly_to_yearly(hourly_rate):
    return hourly_rate * 40 * 52  # 40 hours per week, 52 weeks per year

# create a new yearly min/max salary columns to standardize hourly and yearly pay rates
df5['Yearly Min'] = df5.apply(lambda x: x['sal_min'] if x['type.1'] == 'yearly' else hourly_to_yearly(x['sal_min']), axis=1)
df5['Yearly Max'] = df5.apply(lambda x: x['sal_max'] if x['type.1'] == 'yearly' else hourly_to_yearly(x['sal_max']), axis=1)

# %%
# regex pattern to search for hybrid and remote work
hybrid_pattern = r'\bhybrid\b'
remote_pattern = r'\bremote\b'

# %%
# create new hybrid/remote columns with Boolean values
df5['hybrid'] = df5['title'].str.contains(hybrid_pattern, case=False)
df5['remote'] = df5['title'].str.contains(remote_pattern, case=False)

# %%
df5 = df5.rename(columns={"job_website_source": "Job Website",
                   "job_query": "Search Parameter",
                   "title": "Job Title",
                   "company": "Company",
                  "location": "Location",
                  "job_description": "Job Description",
                  "city": "City",
                   "state": "State Code",
                   "hybrid": "Hybrid",
                   "remote": "Remote",
                  })

# %%
# drop extra columns not needed for final dataset
df5 = df5.drop(['index', 'posted_date', 'type', 'salary', 'type.1', 'sal_min', 'sal_max', 'sal_median', 'origin'], axis=1)

# %%
# drop records where salary values are NaN
df5 = df5.dropna(subset=['Yearly Min'])
df5 = df5.dropna(subset=['Yearly Max'])

# %%
# add Dice dataset to final combined dataset with Indeed and SimplyHired
df = pd.concat([df, df5])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1972 entries, 3 to 795
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job Website       1972 non-null   object
#  1   Search Parameter  1972 non-null   object
#  2   Job Title         1972 non-null   object
#  3   Company           1972 non-null   object
#  4   Location          1051 non-null   object
#  5   Job Description   1051 non-null   object
#  6   Yearly Min        1972 non-null   float64
#  7   Yearly Max        1972 non-null   float64
#  8   Skills            1361 non-null   object
#  9   City              1742 non-null   object
#  10  State Code        1465 non-null   object
#  11  Hybrid            1972 non-null   object
#  12  Remote            1972 non-null   object
# dtypes: float64(2), object(11)
# memory usage: 215.7+ KB

# %%
df.tail()
# Out:
#     Job Website Search Parameter  \
# 772    dice.com   Data Scientist
# 775    dice.com   Data Scientist
# 783    dice.com   Data Scientist
# 786    dice.com   Data Scientist
# 795    dice.com   Data Scientist
#
#                                         Job Title  \
# 772                                Data Scientist
# 775                            Jr. Data Scientist
# 783                 Data Scientist / Data Analyst
# 786  Data Scientist (Hybrid Onsite 2 days a week)
# 795           Jr. Machine Learning Data Scientist
#
#                            Company Location Job Description  Yearly Min  \
# 772                    Robert Half      NaN             NaN    128440.0
# 775                      Skilltune      NaN             NaN     40000.0
# 783                  firstPRO, Inc      NaN             NaN     80000.0
# 786            Xoriant Corporation      NaN             NaN     70000.0
# 795  K2 Partnering Solutions, Inc.      NaN             NaN     50000.0
#
#      Yearly Max                                             Skills      City  \
# 772    148720.0  It, Engineering, Computer, SQL, Python, Analys...   Houston
# 775     55000.0                                       emass, xacta  New York
# 783    100000.0                                                  R    Camden
# 786     80000.0                               Python, Unix, Oracle     Tampa
# 795     60000.0                                         Python, ML       NaN
#
#     State Code Hybrid Remote
# 772         TX  False  False
# 775         NY  False  False
# 783         NJ  False  False
# 786         FL   True  False
# 795        NaN  False  False

# %%
df.to_csv('Final_Jobs_Dataset.csv')

# %%
# Count the total number of rows in the dataframe -- Each row represents 1 job
num_rows = len(df_new)

print("Total Jobs Analyzed:", num_rows)

# Query, average salary of each search parameter "Data Analyst", "Data Engineer", "Data Scientist"
# Out:
# Total Jobs Analyzed: 1225

# %%
df_new['Yearly Max'] = df_new['Yearly Max'].replace(0, 'Null')
# Replace 'Null' values with np.nan
df_new = df_new.replace('Null', np.nan)

# Convert the 'Yearly Max' and 'Yearly Min' columns to float
df_new['Yearly Max'] = df_new['Yearly Max'].astype(float)
df_new['Yearly Min'] = df_new['Yearly Min'].astype(float)

# Calculate the average salary
df_new['Average Salary'] = (df_new['Yearly Max'] + df_new['Yearly Min']) / 2

# %%
# Group by each unique value in the 'Search Parameter' column and take the group's average of the "Average Salary" column
grouped_df = df_new.groupby(['Search Parameter'])['Average Salary'].mean()
grouped_df = grouped_df.apply(lambda x: '${:,.2f}'.format(x))

print(grouped_df)
# Out:
# Search Parameter
# Data Analyst       $95,744.49
# Data Engineer     $136,095.57
# Data Scientist    $138,970.21
# Name: Average Salary, dtype: object

# %%
top_paying_cities = df_new.groupby(['City', 'State Code'])['Average Salary'].mean().sort_values(ascending = False)

print(top_paying_cities)
# Out:
# City                State Code
# East Hanover        NJ            265000.0
# Foster City         CA            221500.0
# Falls Church        VA            210000.0
# Andover             MA            205400.0
# Annapolis Junction  MD            195000.0
#                                     ...
# Boca Raton          FL             50000.0
# Taylor              MI             44720.0
# Cherry Hill         NJ                 NaN
# Spokane             WA                 NaN
# Tallahassee         FL                 NaN
# Name: Average Salary, Length: 227, dtype: float64
